# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_columns', None)

# %%
df=pd.read_excel("TFChainswithID.xlsx")

# %%
df.head()
# Out:
#    1    DLX2   SNAI1  L1 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0  2    GSX2     SP8  L1        NaN        NaN        NaN        NaN
# 1  3    ESR2    EGR1  L1        NaN        NaN        NaN        NaN
# 2  4      AR  TWIST1  L1        NaN        NaN        NaN        NaN
# 3  5   ASCL1   INSM1  L1        NaN        NaN        NaN        NaN
# 4  6  POU5F1   DNMT1  L1        NaN        NaN        NaN        NaN
#
#   Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13  \
# 0        NaN        NaN         NaN         NaN         NaN         NaN
# 1        NaN        NaN         NaN         NaN         NaN         NaN
# 2        NaN        NaN         NaN         NaN         NaN         NaN
# 3        NaN        NaN         NaN         NaN         NaN         NaN
# 4        NaN        NaN         NaN         NaN         NaN         NaN
#
#   Unnamed: 14 Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19  \
# ...

# %%
# df['line'] = 'line'

# %%
df.describe(include = 'all')
# Out:
#                   1   DLX2  SNAI1     L1 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# count   81487.00000  81487  81487  81487      80675      79771      78570
# unique          NaN    311    291    234        187        157        126
# top             NaN  STAT3    MYC  NANOG      NANOG     POU5F1      SALL4
# freq            NaN   3419   4231  12659      17907      16966      12447
# mean    40745.00000    NaN    NaN    NaN        NaN        NaN        NaN
# std     23523.41503    NaN    NaN    NaN        NaN        NaN        NaN
# min         2.00000    NaN    NaN    NaN        NaN        NaN        NaN
# 25%     20373.50000    NaN    NaN    NaN        NaN        NaN        NaN
# 50%     40745.00000    NaN    NaN    NaN        NaN        NaN        NaN
# 75%     61116.50000    NaN    NaN    NaN        NaN        NaN        NaN
# max     81488.00000    NaN    NaN    NaN        NaN        NaN        NaN
#
#        Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12  \
# ...

# %%
len(df_merge_final)-len(df_merge_final.drop_duplicates())
# Out:
# 0

# %%
# N=10
# df1 = pd.DataFrame({
#    'A': pd.date_range(start='2016-01-01',periods=N,freq='D'),
#    'x': np.linspace(0,stop=N-1,num=N),
#    'y': np.random.rand(N),
#    'C': np.random.choice(['Low','Medium','High'],N).tolist(),
#    'D': np.random.normal(100, 10, size=(N)).tolist()
# })

# %%
line_list=[]
for i in range(1,62):
    var="L{}".format(i)
#     print(var)
#     print("L{}".format(i))
    line_list.append(var)
    
line_list
# Out:
# ['L1',
#  'L2',
#  'L3',
#  'L4',
#  'L5',
#  'L6',
#  'L7',
#  'L8',
#  'L9',
#  'L10',
#  'L11',
#  'L12',
#  'L13',
#  'L14',
#  'L15',
#  'L16',
#  'L17',
#  'L18',
#  'L19',
#  'L20',
#  'L21',
#  'L22',
#  'L23',
#  'L24',
#  'L25',
#  'L26',
#  'L27',
#  'L28',
#  'L29',
#  'L30',
#  'L31',
#  'L32',
#  'L33',
#  'L34',
#  'L35',
#  'L36',
#  'L37',
#  'L38',
#  'L39',
#  'L40',
#  'L41',
#  'L42',
#  'L43',
#  'L44',
#  'L45',
#  'L46',
#  'L47',
#  'L48',
#  'L49',
#  'L50',
#  'L51',
#  'L52',
#  'L53',
#  'L54',
#  'L55',
#  'L56',
#  'L57',
#  'L58',
#  'L59',
#  'L60',
#  'L61']

# %%
df_temp=df[(df == 'L1').any(axis=1)]
df_merge_final=df_temp
print(df_temp.isnull().sum())
print(df_temp.shape)
# Out:
# C:\Users\sonish.s\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)
# 1                0
# DLX2             0
# SNAI1            0
# L1               0
# Unnamed: 4     812
#               ...
# Unnamed: 59    812
# Unnamed: 60    812
# Unnamed: 61    812
# Unnamed: 62    812
# Unnamed: 63    812
# Length: 64, dtype: int64
# (812, 64)

# %%
# if df_temp['L1'].unique() == 'L1':
#     print(1)
# else: print(0)

# %%
# df_L1=df.dropna(axis=1, how='all')
# df_L1.head()

# %%
# df_merge_final['line'].unique()

# %%
df_temp=df[(df == 'L1').any(axis=1)]
df_temp
# Out:
#        1    DLX2   SNAI1  L1 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0      2    GSX2     SP8  L1        NaN        NaN        NaN        NaN
# 1      3    ESR2    EGR1  L1        NaN        NaN        NaN        NaN
# 2      4      AR  TWIST1  L1        NaN        NaN        NaN        NaN
# 3      5   ASCL1   INSM1  L1        NaN        NaN        NaN        NaN
# 4      6  POU5F1   DNMT1  L1        NaN        NaN        NaN        NaN
# ..   ...     ...     ...  ..        ...        ...        ...        ...
# 807  809  NFATC2     MYC  L1        NaN        NaN        NaN        NaN
# 808  810    NFYC   DDIT3  L1        NaN        NaN        NaN        NaN
# 809  811   NR2F1     MYC  L1        NaN        NaN        NaN        NaN
# 810  812   MEF2A   ESRRA  L1        NaN        NaN        NaN        NaN
# 811  813    E2F1    TP53  L1        NaN        NaN        NaN        NaN
#
#     Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13  \
# ...

# %%
def func(a,df_merge_final):
    df_temp=df[(df == a).any(axis=1)]
#     print(df_temp.head())
    for col in df_temp:
#          print(df_temp[col].unique())
        if df_temp[col].unique().all() == a:df_temp['line']= a
#     #True df_temp['line']='L3'
        else: None
    df_merge_final= pd.concat([df_merge_final,df_temp], axis=0)
    return df_merge_final

# %%
# a='L1'
for i in line_list:
    df_merge_final=func(i,df_merge_final)
# Out:
# C:\Users\sonish.s\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)
# C:\Users\sonish.s\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# a='L5'
# df_temp=df[(df == a).any(axis=1)]
# #     print(df_temp.head())
# for col in df_temp:
# #          print(df_temp[col].unique())
#         if df_temp[col].unique().all() == a:df_temp['line']= a
#     #True df_temp['line']='L3'
#         else: None
# df_merge_final= pd.concat([df_merge_final,df_temp], axis=0)

# %%
df_merge_final
# Out:
#            1    DLX2   SNAI1      L1 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0          2    GSX2     SP8      L1        NaN        NaN        NaN
# 1          3    ESR2    EGR1      L1        NaN        NaN        NaN
# 2          4      AR  TWIST1      L1        NaN        NaN        NaN
# 3          5   ASCL1   INSM1      L1        NaN        NaN        NaN
# 4          6  POU5F1   DNMT1      L1        NaN        NaN        NaN
# ...      ...     ...     ...     ...        ...        ...        ...
# 81482  81484     JUN   DNMT1    TP53      NANOG     POU5F1      SALL4
# 81483  81485    TP53   HMGA2  TWIST1     POU5F1      SALL4      NANOG
# 81484  81486     JUN   DNMT1    TP53      NANOG     POU5F1      SALL4
# 81485  81487    TP53   HMGA2  TWIST1     POU5F1      SALL4      NANOG
# 81486  81488    TP53   HMGA2  TWIST1     POU5F1      SALL4      NANOG
#
#       Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12  \
# ...

# %%
df_merge_final.to_csv("temp.csv")

# %%
k='L1'
func(k,df_merge_final)

# %%
# df_merge_final_copy=df_merge_final

# %%
df_merge_final=df_merge_final_copy

# %%
# df_merge_final= pd.concat([df_merge_final,df_temp], axis=0)
df_merge_final

# %%
# df_reindexed = df1.reindex(index=[0,2,5], columns=['A', 'C', 'B'])

# print(df_reindexed)

# %%
pd.options.display.max_columns = None

# %%
df['line2']

# %%
df_L1['line'].unique()
